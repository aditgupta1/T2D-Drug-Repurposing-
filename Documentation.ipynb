# %%
import pandas as pd
import numpy as np

# %%
path_to_file = "/Users/aditgupta/Google Drive/Research/T2D/Summer_2018/meddra_freq.tsv"

# %%
df = pd.read_csv(path_to_file, delimiter="\t", header=None)

# %%
df.head(10)
# Out:
#               0             1         2    3    4     5     6    7         8  \
# 0  CID100000085  CID000010917  C0000737  NaN  21%  0.21  0.21  LLT  C0000737
# 1  CID100000085  CID000010917  C0000737  NaN  21%  0.21  0.21   PT  C0000737
# 2  CID100000085  CID000010917  C0000737  NaN  21%  0.21  0.21   PT  C0687713
# 3  CID100000085  CID000010917  C0000737  NaN   5%  0.05  0.05  LLT  C0000737
# 4  CID100000085  CID000010917  C0000737  NaN   5%  0.05  0.05   PT  C0000737
# 5  CID100000085  CID000010917  C0000737  NaN   5%  0.05  0.05   PT  C0687713
# 6  CID100000085  CID000010917  C0000737  NaN   6%  0.06  0.06  LLT  C0000737
# 7  CID100000085  CID000010917  C0000737  NaN   6%  0.06  0.06   PT  C0000737
# 8  CID100000085  CID000010917  C0000737  NaN   6%  0.06  0.06   PT  C0687713
# 9  CID100000085  CID000010917  C0000737  NaN   9%  0.09  0.09  LLT  C0000737
#
#                        9
# 0         Abdominal pain
# 1         Abdominal pain
# 2  Gastrointestinal pain
# ...

# %%
df.loc[df[9].isin(["Blood pressure increased","Abdominal pain"])].head(15)
# Out:
#                  0             1         2        3              4     5  \
# 0     CID100000085  CID000010917  C0000737      NaN            21%  0.21
# 1     CID100000085  CID000010917  C0000737      NaN            21%  0.21
# 3     CID100000085  CID000010917  C0000737      NaN             5%  0.05
# 4     CID100000085  CID000010917  C0000737      NaN             5%  0.05
# 6     CID100000085  CID000010917  C0000737      NaN             6%  0.06
# 7     CID100000085  CID000010917  C0000737      NaN             6%  0.06
# 9     CID100000085  CID000010917  C0000737      NaN             9%  0.09
# 10    CID100000085  CID000010917  C0000737      NaN             9%  0.09
# 12    CID100000085  CID000010917  C0000737  placebo            17%  0.17
# 13    CID100000085  CID000010917  C0000737  placebo            17%  0.17
# 996   CID100000159  CID005282411  C0000737      NaN             5%  0.05
# 997   CID100000159  CID005282411  C0000737      NaN             5%  0.05
# ...

# %%
df[9].isin(["Blood pressure increased","Abdominal pain"]).head(10)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: 9, dtype: bool

# %%
df2 = df.loc[df[9].isin(["Blood pressure increased","Abdominal pain"])]

# %%
df2.head(15)
# Out:
#                  0             1         2        3              4     5  \
# 0     CID100000085  CID000010917  C0000737      NaN            21%  0.21
# 1     CID100000085  CID000010917  C0000737      NaN            21%  0.21
# 3     CID100000085  CID000010917  C0000737      NaN             5%  0.05
# 4     CID100000085  CID000010917  C0000737      NaN             5%  0.05
# 6     CID100000085  CID000010917  C0000737      NaN             6%  0.06
# 7     CID100000085  CID000010917  C0000737      NaN             6%  0.06
# 9     CID100000085  CID000010917  C0000737      NaN             9%  0.09
# 10    CID100000085  CID000010917  C0000737      NaN             9%  0.09
# 12    CID100000085  CID000010917  C0000737  placebo            17%  0.17
# 13    CID100000085  CID000010917  C0000737  placebo            17%  0.17
# 996   CID100000159  CID005282411  C0000737      NaN             5%  0.05
# 997   CID100000159  CID005282411  C0000737      NaN             5%  0.05
# ...

# %%
df[3].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: 3, dtype: object

# %%
df[3].unique()
# Out:
# array([nan, 'placebo'], dtype=object)

# %%
type(df[3])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[3].unique())
# Out:
# numpy.ndarray

# %% [markdown]
# ### Getting lines 2400-2500 of a file

# %%
# %%bash
# head -n  15349600 /users/aditgupta/Google\ Drive/Research/T2D/Summer_2018/drugbank_full_database.xml | tail -n 100
# Out:
#   <prices/>
#   <categories>
#     <category>
#       <category>Alimentary Tract and Metabolism</category>
#       <mesh-id/>
#     </category>
#     <category>
#       <category>Benzene Derivatives</category>
#       <mesh-id>D001555</mesh-id>
#     </category>
#     <category>
#       <category>Blood Glucose Lowering Agents</category>
#       <mesh-id>D007004</mesh-id>
#     </category>
#     <category>
#       <category>Carbohydrates</category>
#       <mesh-id>D002241</mesh-id>
#     </category>
#     <category>
#       <category>Diuretics</category>
#       <mesh-id>D004232</mesh-id>
#     </category>
#     <category>
#       <category>Drugs Used in Diabetes</category>
#       <mesh-id/>
#     </category>
#     <category>
#       <category>Glycosides</category>
#       <mesh-id>D006027</mesh-id>
#     </category>
#     <category>
#       <category>Hydrocarbons</category>
#       <mesh-id>D006838</mesh-id>
#     </category>
#     <category>
# ...

# %% [markdown]
# ### To convert jupyter lab code into html(printable file) use the following code in terminal:

# %% [raw]
# ipython nbconvert file.ipynb

# %% [markdown]
# ### Where file.ipynb is your file name (change it to whatever it is) and cd into the correct folder in iterm to wherever your file is located on the computer
