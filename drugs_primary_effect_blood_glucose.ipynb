# %%
import pandas as pd
import numpy as np

# %%
path_to_file = "/Users/aditgupta/Google Drive/Research/T2D/Summer_2018/drug_names.tsv" #this is the path to the file for all the drug names and corresponding ID's
df5 = pd.read_csv(path_to_file,delimiter="\t", header=None) #reads file, converts to csv, and explains to functionthat the delimeter are tabs
df5.rename(columns={0:'ID'}, inplace=True) #renames index zero to 'ID'
df5.rename(columns={1:'drug_name'}, inplace=True) #renames index one to drug name
#OVERALL: df5 contains the drug name based on the 'CID' ID

# %%
df5.head(10)
# Out:
#              ID                 drug_name
# 0  CID100000085                 carnitine
# 1  CID100000119        gamma-aminobutyric
# 2  CID100000137          5-aminolevulinic
# 3  CID100000143                leucovorin
# 4  CID100000146  5-methyltetrahydrofolate
# 5  CID100000158                      PGE2
# 6  CID100000159              prostacyclin
# 7  CID100000160             prostaglandin
# 8  CID100000175                   acetate
# 9  CID100000187             acetylcholine

# %%
df5.loc[df5["drug_name"].isin(["repaglinide"])] #the drug, repaglinide, which targets the PPARG gene (which variants are associated with T2D(Majithia et al PNAS 2014)) is present in the database.
#However its side effects aren't one of the four traits linked to type 2 diabetes, so the drug and samples don't get included in the final sample
# Out:
#                ID    drug_name
# 561  CID100004547  repaglinide

# %%
import xml.etree.ElementTree as ET
import lxml.html
#importing libraries that parse the xml file with detailed drug information

# %%
path_to_file = '/Users/aditgupta/Google Drive/Research/T2D/Summer_2018/drugbank_full_database.xml' #file location of the drugbank database

# %%
tree = ET.parse(path_to_file) # function that parses the xml file from drugbank

# %%
def find_categories_matching_string(drug_element, category_name):
    all_categories = drug_element.findall(".//*{http://www.drugbank.ca}category")
    categories_wanted = list(filter(lambda category: category.text == category_name, all_categories))
    return categories_wanted

# %%
def get_id_and_name_from_target(target):
    id = target.find("{http://www.drugbank.ca}id").text
    name = target.find("{http://www.drugbank.ca}name").text
    effect = target.find("*{http://www.drugbank.ca}category") #Blood Glucose Lowering
    gene = target.find("*{http://www.drugbank.ca}gene-name")
    #glucose_categories = find_categories_matching_string(target, "Blood Glucose Lowering Agents")
    #diabetes_categories = find_categories_matching_string(target, "Drugs Used in Diabetes")

    
    if gene is None:
        gene_found = None
        
    else:
        gene_found= gene.text
    return id, name, gene_found
#function that returns the target id, target name, and gene name of a particular sample

# %%
all_drugs = tree.findall("{http://www.drugbank.ca}drug")

# %%
new_results = []
total_found = 0
for drug in all_drugs:
    drug_name = drug.find("{http://www.drugbank.ca}name").text
    drug_id = drug.find("{http://www.drugbank.ca}drugbank-id[@primary]").text
    element_containing_all_targets = drug.find("{http://www.drugbank.ca}targets")
    list_of_targets = element_containing_all_targets.findall("{http://www.drugbank.ca}target")
    glucose_categories = find_categories_matching_string(drug, "Blood Glucose Lowering Agents")
    diabetes_categories = find_categories_matching_string(drug, "Drugs Used in Diabetes")
    if glucose_categories == []:
        glucose_categories = None
    if diabetes_categories == []:
        diabetes_categories = None
    for target in list_of_targets:
        target_id, target_name, target_gene = get_id_and_name_from_target(target)
        new_results.append([drug_name, drug_id, target_id, target_name, target_gene, glucose_categories, diabetes_categories])
    total_found += 1
#creates an array and list that contains the drug name, drug id, target id, target name, and target gene as extracted from drug bank

# %%
second_results = []

# %%
total_found = 0
for drug in all_drugs:
    drug_name = drug.find("{http://www.drugbank.ca}name").text
    drug_id = drug.find("{http://www.drugbank.ca}drugbank-id[@primary]").text
    element_containing_all_targets = drug.find("{http://www.drugbank.ca}targets")
    list_of_targets = element_containing_all_targets.findall("{http://www.drugbank.ca}target")
    for target in list_of_targets:
        target_id, target_name, target_gene = get_id_and_name_from_target(target)
        second_results.append([drug_name, drug_id, target_id, target_name, target_gene])
    total_found += 1
#creates an array and list that contains the drug name, drug id, target id, target name, and target gene as extracted from drug bank

# %%
test_results = []
test_found = 0
for drug in all_drugs:
    drug_name = drug.find("{http://www.drugbank.ca}name").text
    drug_id = drug.find("{http://www.drugbank.ca}drugbank-id[@primary]").text
    element_containing_all_targets = drug.find("{http://www.drugbank.ca}targets")
    list_of_targets = element_containing_all_targets.findall("{http://www.drugbank.ca}target")
    diabetes_categories = find_categories_matching_string(drug, "Drugs Used in Diabetes")
    if diabetes_categories == []:
        diabetes_categories = None
    for target in list_of_targets:
        target_id, target_name, target_gene = get_id_and_name_from_target(target)
        test_results.append([drug_name, drug_id, target_id, target_name, target_gene, diabetes_categories])
    test_found += 1

# %%
drug = all_drugs[0]
element_containing_all_targets = drug.find("{http://www.drugbank.ca}targets")
list_of_targets = element_containing_all_targets.findall("{http://www.drugbank.ca}target")
target = list_of_targets[0]

# %%
drug
# Out:
# <Element '{http://www.drugbank.ca}drug' at 0x23efd1d68>

# %%
df = pd.DataFrame(new_results) #df contains the results from the parsing of the xml file from drugbank

# %%
df.columns = ["drug_name", "drug_id", "target_id", "target_name", "target_gene","target_effect_glucose_?","target_effect_diabetes"] #renaming the columns of the dataframe
#"target_effect_glucose_?"

# %%
df50 = df

# %%
df.shape
# Out:
# (18495, 7)

# %%
genes_wanted = df.dropna()['target_gene'].unique()

# %%
df50.dropna().head()
# Out:
#          drug_name  drug_id  target_id                            target_name  \
# 102  Insulin Human  DB00030  BE0000033                       Insulin receptor
# 103  Insulin Human  DB00030  BE0000858  Insulin-like growth factor 1 receptor
# 104  Insulin Human  DB00030  BE0002123      Retinoblastoma-associated protein
# 105  Insulin Human  DB00030  BE0000941                            Cathepsin D
# 106  Insulin Human  DB00030  BE0001183               Insulin-degrading enzyme
#
#     target_gene target_effect_glucose_? target_effect_diabetes
# 102        INSR                    [[]]                   [[]]
# 103       IGF1R                    [[]]                   [[]]
# 104         RB1                    [[]]                   [[]]
# 105        CTSD                    [[]]                   [[]]
# 106         IDE                    [[]]                   [[]]

# %%
string_to_write = "\n".join(genes_wanted)

# %%
with open("output.txt", "w") as f:
    f.write(string_to_write)

# %%
df.head()
# Out:
#    drug_name  drug_id  target_id  \
# 0  Lepirudin  DB00001  BE0000048
# 1  Cetuximab  DB00002  BE0000767
# 2  Cetuximab  DB00002  BE0000901
# 3  Cetuximab  DB00002  BE0002093
# 4  Cetuximab  DB00002  BE0002094
#
#                                          target_name target_gene  \
# 0                                        Prothrombin          F2
# 1                   Epidermal growth factor receptor        EGFR
# 2  Low affinity immunoglobulin gamma Fc region re...      FCGR3B
# 3                        Complement C1r subcomponent         C1R
# 4              Complement C1q subcomponent subunit A        C1QA
#
#   target_effect_glucose_? target_effect_diabetes
# 0                    None                   None
# 1                    None                   None
# 2                    None                   None
# 3                    None                   None
# 4                    None                   None

# %%
df.dropna(subset = ['target_effect_glucose_?']) #only drops nans for whether they effect glucose. There are more drugs that target glucose than target diabetes
# Out:
#                  drug_name  drug_id  target_id  \
# 102          Insulin Human  DB00030  BE0000033
# 103          Insulin Human  DB00030  BE0000858
# 104          Insulin Human  DB00030  BE0002123
# 105          Insulin Human  DB00030  BE0000941
# 106          Insulin Human  DB00030  BE0001183
# 107          Insulin Human  DB00030  BE0002124
# 108          Insulin Human  DB00030  BE0001123
# 109          Insulin Human  DB00030  BE0002125
# 110          Insulin Human  DB00030  BE0001147
# 111          Insulin Human  DB00030  BE0000942
# 112          Insulin Human  DB00030  BE0002126
# 113          Insulin Human  DB00030  BE0002127
# 160         Insulin Lispro  DB00046  BE0000033
# 161         Insulin Lispro  DB00046  BE0000858
# 162       Insulin Glargine  DB00047  BE0000033
# 163       Insulin Glargine  DB00047  BE0000858
# 243           Insulin Pork  DB00071  BE0000033
# 244           Insulin Pork  DB00071  BE0000858
# 245           Insulin Pork  DB00071  BE0001183
# 246           Insulin Pork  DB00071  BE0002122
# 247           Insulin Pork  DB00071  BE0004466
# 248           Insulin Pork  DB00071  BE0002123
# 249           Insulin Pork  DB00071  BE0000941
# 250           Insulin Pork  DB00071  BE0001123
# 251           Insulin Pork  DB00071  BE0002124
# 252           Insulin Pork  DB00071  BE0002125
# 253           Insulin Pork  DB00071  BE0001147
# 254           Insulin Pork  DB00071  BE0000942
# 255           Insulin Pork  DB00071  BE0002126
# 256           Insulin Pork  DB00071  BE0002127
# ...                    ...      ...        ...
# 5555           Pramlintide  DB01278  BE0000861
# 5571           Glisoxepide  DB01289  BE0002441
# 5593        Insulin Aspart  DB01306  BE0000033
# 5594       Insulin Detemir  DB01307  BE0000033
# 5595     Insulin Glulisine  DB01309  BE0000033
# 5789          Glycodiazine  DB01382  BE0000644
# 5790          Glycodiazine  DB01382  BE0000207
# 6529   AICA ribonucleotide  DB01700  BE0001240
# 11983         Vildagliptin  DB04876  BE0000854
# 11985            Voglibose  DB04878  BE0000837
# 12230                NN344  DB05115  BE0000033
# 12780              AMG-222  DB06011  BE0000854
# 12842              KRP-104  DB06127  BE0000854
# 12948           Alogliptin  DB06203  BE0000854
# 13084        Dapagliflozin  DB06292  BE0004753
# 13094          Saxagliptin  DB06335  BE0000854
# 13293          Liraglutide  DB06655  BE0000857
# 15462          Gosogliptin  DB08382  BE0000854
# 16148          Linagliptin  DB08882  BE0000854
# 16218        Canagliflozin  DB08907  BE0004753
# 16219        Canagliflozin  DB08907  BE0004754
# 16294        Empagliflozin  DB09038  BE0004753
# 16298          Albiglutide  DB09043  BE0000857
# 16299          Dulaglutide  DB09045  BE0000857
# 16674        Lobeglitazone  DB09198  BE0000215
# 16675          Ciglitazone  DB09201  BE0000215
# 16779         Lixisenatide  DB09265  BE0000857
# 16933     Insulin Degludec  DB09564  BE0000033
# 17463          Dutogliptin  DB11723  BE0000854
# 18213          Semaglutide  DB13928  BE0000857
#
#                                              target_name target_gene  \
# 102                                     Insulin receptor        INSR
# 103                Insulin-like growth factor 1 receptor       IGF1R
# 104                    Retinoblastoma-associated protein         RB1
# 105                                          Cathepsin D        CTSD
# 106                             Insulin-degrading enzyme         IDE
# 107                          Neuroendocrine convertase 2       PCSK2
# 108                                   Carboxypeptidase E         CPE
# 109                          Neuroendocrine convertase 1       PCSK1
# 110                                  Protein NOV homolog         NOV
# 111    Low-density lipoprotein receptor-related prote...        LRP2
# 112         Insulin-like growth factor-binding protein 7      IGFBP7
# 113                         Synaptotagmin-like protein 4       SYTL4
# 160                                     Insulin receptor        INSR
# 161                Insulin-like growth factor 1 receptor       IGF1R
# 162                                     Insulin receptor        INSR
# 163                Insulin-like growth factor 1 receptor       IGF1R
# 243                                     Insulin receptor        INSR
# 244                Insulin-like growth factor 1 receptor       IGF1R
# 245                             Insulin-degrading enzyme         IDE
# 246    HLA class II histocompatibility antigen, DQ al...    HLA-DQA2
# 247    HLA class II histocompatibility antigen, DQ be...    HLA-DQB1
# 248                    Retinoblastoma-associated protein         RB1
# 249                                          Cathepsin D        CTSD
# 250                                   Carboxypeptidase E         CPE
# 251                          Neuroendocrine convertase 2       PCSK2
# 252                          Neuroendocrine convertase 1       PCSK1
# 253                                  Protein NOV homolog         NOV
# 254    Low-density lipoprotein receptor-related prote...        LRP2
# 255         Insulin-like growth factor-binding protein 7      IGFBP7
# 256                         Synaptotagmin-like protein 4       SYTL4
# ...                                                  ...         ...
# 5555               Receptor activity-modifying protein 3       RAMP3
# 5571   ATP-sensitive inward rectifier potassium chann...       KCNJ8
# 5593                                    Insulin receptor        INSR
# 5594                                    Insulin receptor        INSR
# 5595                                    Insulin receptor        INSR
# 5789   ATP-sensitive inward rectifier potassium chann...       KCNJ1
# 5790          ATP-binding cassette sub-family C member 8       ABCC8
# 6529       Bifunctional purine biosynthesis protein PURH        ATIC
# 11983                             Dipeptidyl peptidase 4        DPP4
# 11985                   Maltase-glucoamylase, intestinal        MGAM
# 12230                                   Insulin receptor        INSR
# 12780                             Dipeptidyl peptidase 4        DPP4
# 12842                             Dipeptidyl peptidase 4        DPP4
# 12948                             Dipeptidyl peptidase 4        DPP4
# 13084                     Sodium/glucose cotransporter 2      SLC5A2
# 13094                             Dipeptidyl peptidase 4        DPP4
# 13293                   Glucagon-like peptide 1 receptor       GLP1R
# 15462                             Dipeptidyl peptidase 4        DPP4
# 16148                             Dipeptidyl peptidase 4        DPP4
# 16218                     Sodium/glucose cotransporter 2      SLC5A2
# 16219                     Sodium/glucose cotransporter 1      SLC5A1
# 16294                     Sodium/glucose cotransporter 2      SLC5A2
# 16298                   Glucagon-like peptide 1 receptor       GLP1R
# 16299                   Glucagon-like peptide 1 receptor       GLP1R
# 16674   Peroxisome proliferator-activated receptor gamma       PPARG
# 16675   Peroxisome proliferator-activated receptor gamma       PPARG
# 16779                   Glucagon-like peptide 1 receptor       GLP1R
# 16933                                   Insulin receptor        INSR
# 17463                             Dipeptidyl peptidase 4        DPP4
# 18213                   Glucagon-like peptide 1 receptor       GLP1R
#
#       target_effect_glucose_? target_effect_diabetes
# 102                      [[]]                   [[]]
# 103                      [[]]                   [[]]
# 104                      [[]]                   [[]]
# 105                      [[]]                   [[]]
# 106                      [[]]                   [[]]
# 107                      [[]]                   [[]]
# 108                      [[]]                   [[]]
# 109                      [[]]                   [[]]
# 110                      [[]]                   [[]]
# 111                      [[]]                   [[]]
# 112                      [[]]                   [[]]
# 113                      [[]]                   [[]]
# 160                      [[]]                   [[]]
# 161                      [[]]                   [[]]
# 162                      [[]]                   [[]]
# 163                      [[]]                   [[]]
# 243                      [[]]                   [[]]
# 244                      [[]]                   [[]]
# 245                      [[]]                   [[]]
# 246                      [[]]                   [[]]
# 247                      [[]]                   [[]]
# 248                      [[]]                   [[]]
# 249                      [[]]                   [[]]
# 250                      [[]]                   [[]]
# 251                      [[]]                   [[]]
# 252                      [[]]                   [[]]
# 253                      [[]]                   [[]]
# 254                      [[]]                   [[]]
# 255                      [[]]                   [[]]
# 256                      [[]]                   [[]]
# ...                       ...                    ...
# 5555                     [[]]                   [[]]
# 5571                     [[]]                   [[]]
# 5593                     [[]]                   [[]]
# 5594                     [[]]                   [[]]
# 5595                     [[]]                   [[]]
# 5789                     [[]]                   [[]]
# 5790                     [[]]                   [[]]
# 6529                     [[]]                   None
# 11983                    [[]]                   [[]]
# 11985                    [[]]                   [[]]
# 12230                    [[]]                   None
# 12780                    [[]]                   None
# 12842                    [[]]                   None
# 12948                    [[]]                   [[]]
# 13084                    [[]]                   [[]]
# 13094                    [[]]                   [[]]
# 13293                    [[]]                   [[]]
# 15462                    [[]]                   None
# 16148                    [[]]                   [[]]
# 16218                    [[]]                   [[]]
# 16219                    [[]]                   [[]]
# 16294                    [[]]                   [[]]
# 16298                    [[]]                   [[]]
# 16299                    [[]]                   [[]]
# 16674                    [[]]                   None
# 16675                    [[]]                   None
# 16779                    [[]]                   [[]]
# 16933                    [[]]                   [[]]
# 17463                    [[]]                   None
# 18213                    [[]]                   None
#
# [176 rows x 7 columns]

# %%
df2 = pd.DataFrame(second_results)
df2.columns = ["drug_name", "drug_id", "target_id", "target_name", "target_gene"] #renaming the columns of the dataframe
df2.head()
# Out:
#    drug_name  drug_id  target_id  \
# 0  Lepirudin  DB00001  BE0000048
# 1  Cetuximab  DB00002  BE0000767
# 2  Cetuximab  DB00002  BE0000901
# 3  Cetuximab  DB00002  BE0002093
# 4  Cetuximab  DB00002  BE0002094
#
#                                          target_name target_gene
# 0                                        Prothrombin          F2
# 1                   Epidermal growth factor receptor        EGFR
# 2  Low affinity immunoglobulin gamma Fc region re...      FCGR3B
# 3                        Complement C1r subcomponent         C1R
# 4              Complement C1q subcomponent subunit A        C1QA

# %%
df2["drug_name"] = df2["drug_name"].str.lower() #all drug names in the dataframe are made lower case for simplicity

# %%
indexed_df = df2.set_index("drug_name") #new dataframe where the index is drug_name

# %%
indexed_df.head()
# Out:
#            drug_id  target_id  \
# drug_name
# lepirudin  DB00001  BE0000048
# cetuximab  DB00002  BE0000767
# cetuximab  DB00002  BE0000901
# cetuximab  DB00002  BE0002093
# cetuximab  DB00002  BE0002094
#
#                                                  target_name target_gene
# drug_name
# lepirudin                                        Prothrombin          F2
# cetuximab                   Epidermal growth factor receptor        EGFR
# cetuximab  Low affinity immunoglobulin gamma Fc region re...      FCGR3B
# cetuximab                        Complement C1r subcomponent         C1R
# cetuximab              Complement C1q subcomponent subunit A        C1QA

# %%
#Find all drugs that have at most two targets and all targets that have at least two drugs targeting it
df3 = df['drug_name'].value_counts() 
df4 = df3.to_frame(name=None)
df5 = df4.reset_index()
df6 = df5.rename(columns={'drug_name':'number_of_targets'}, inplace=False)

# %%
df7 = df6.rename(columns={'index':'drug_name'}, inplace=False)
df7.head()
#df7 is a dataframe that displays the number of targets given a drug
# Out:
#       drug_name  number_of_targets
# 0  Fostamatinib                300
# 1     Artenimol                192
# 2        Copper                147
# 3          NADH                144
# 4          Zinc                124

# %%
#purpose of this cell is to find the number of drugs that target a specific target. Only targets that have more than two drugs targeting it are desired 
target_freq = df['target_id'].value_counts() #number of drugs that target a given target ID in a series
df8 = target_freq.to_frame(name=None)
df9 = df8.reset_index()
df10 = df9.rename(columns={'target_id':'target_freq'}, inplace=False)
df11 = df10.rename(columns={'index':'target_id'}, inplace=False)
df11.head(10)
#df20 is a datagrame that shows the total number of drugs that target a given target ID
# Out:
#    target_id  target_freq
# 0  BE0001072          137
# 1  BE0000048          112
# 2  BE0000123          111
# 3  BE0000756          108
# 4  BE0000451          105
# 5  BE0000442          104
# 6  BE0004796          101
# 7  BE0000322          100
# 8  BE0001739           99
# 9  BE0000092           97

# %%
df12 = df7[(df7['number_of_targets'])<3]  
df12.head()
#df10 is a dataframe that only contains drugs that have a maximum of two targets
# Out:
#                                               drug_name  number_of_targets
# 1508                    Interferon Alfa-2b, Recombinant                  2
# 1509  N-(4-(2-((3-Chlorophenylmethyl)Amino)Ethyl)Phe...                  2
# 1510                                          Befunolol                  2
# 1511                                          Progabide                  2
# 1512  2,4-Diamino-5-(3,4,5-Trimethoxy-Benzyl)-Pyrimi...                  2

# %%
df12['drug_name'].unique() #displays all unique genes that at most two targets. There are 5891 genes that fit this criteria
# Out:
# array(['Interferon Alfa-2b, Recombinant',
#        'N-(4-(2-((3-Chlorophenylmethyl)Amino)Ethyl)Phenyl)-2-Thiophecarboxamidine',
#        'Befunolol', ..., 'Prasugrel', 'Secukinumab',
#        '(3Z,5S,6R,7S,8R,8aR)-3-(octylimino)hexahydro[1,3]oxazolo[3,4-a]pyridine-5,6,7,8-tetrol'],
#       dtype=object)

# %%
df13 = df11[(df11['target_freq'])>1]  #df21 is a dataframe that contains all targets that have at least two drugs targeting it
df13.head(15) #displays first 15 targets
# Out:
#     target_id  target_freq
# 0   BE0001072          137
# 1   BE0000048          112
# 2   BE0000123          111
# 3   BE0000756          108
# 4   BE0000451          105
# 5   BE0000442          104
# 6   BE0004796          101
# 7   BE0000322          100
# 8   BE0001739           99
# 9   BE0000092           97
# 10  BE0000501           91
# 11  BE0000291           81
# 12  BE0000560           79
# 13  BE0000262           78
# 14  BE0000017           77

# %%
df14 = pd.merge(df, df12, on='drug_name', how='inner')
df15 = df14.dropna(subset= ['target_effect_glucose_?', 'target_gene'])
df15.head()
# Out:
#             drug_name  drug_id  target_id  \
# 35     Insulin Lispro  DB00046  BE0000033
# 36     Insulin Lispro  DB00046  BE0000858
# 37   Insulin Glargine  DB00047  BE0000033
# 38   Insulin Glargine  DB00047  BE0000858
# 154     Sulfisoxazole  DB00263  BE0000803
#
#                                target_name target_gene  \
# 35                        Insulin receptor        INSR
# 36   Insulin-like growth factor 1 receptor       IGF1R
# 37                        Insulin receptor        INSR
# 38   Insulin-like growth factor 1 receptor       IGF1R
# 154               Dihydropteroate synthase        folP
#
#     target_effect_glucose_? target_effect_diabetes  number_of_targets
# 35                     [[]]                   [[]]                  2
# 36                     [[]]                   [[]]                  2
# 37                     [[]]                   [[]]                  2
# 38                     [[]]                   [[]]                  2
# 154                    [[]]                   None                  1

# %%
df16 = pd.merge(df15, df13, on='target_id', how='outer') #merges df21(which contains all targets with more than two drugs targetin it) and df27 (the current master dataframe)
df16.dropna().head()
#there are several Nan values for targets that had less than two drugs targeting it or targets that werent in the previous master dataframe (like BE0001072). 
#These must be removed (and it is done in df29)
# Out:
#            drug_name  drug_id  target_id       target_name target_gene  \
# 0     Insulin Lispro  DB00046  BE0000033  Insulin receptor        INSR
# 1   Insulin Glargine  DB00047  BE0000033  Insulin receptor        INSR
# 2     Insulin Aspart  DB01306  BE0000033  Insulin receptor        INSR
# 3    Insulin Detemir  DB01307  BE0000033  Insulin receptor        INSR
# 4  Insulin Glulisine  DB01309  BE0000033  Insulin receptor        INSR
#
#   target_effect_glucose_? target_effect_diabetes  number_of_targets  \
# 0                    [[]]                   [[]]                2.0
# 1                    [[]]                   [[]]                2.0
# 2                    [[]]                   [[]]                1.0
# 3                    [[]]                   [[]]                1.0
# 4                    [[]]                   [[]]                1.0
#
#    target_freq
# 0         16.0
# 1         16.0
# 2         16.0
# 3         16.0
# 4         16.0

# %%
genes_desired = df16.dropna()['target_gene'].unique()
string_to_write = "\n".join(genes_desired)
with open("genes_desired.txt", "w") as f:
    f.write(string_to_write)

# %%
drugs_used = df16.dropna()['drug_name'].unique()
string_to_write = "\n".join(drugs_used)
with open("drugs_used.txt", "w")as f:
    f.write(string_to_write)

# %%
df17 = pd.DataFrame(test_results)
df17.columns = ["drug_name","drug_id","target_id","target_name","target_gene", "target_effect_diabetes"]
df18 = df17.dropna() #displays all drugs used in diabetes

# %%
df18['drug_name'].unique()
# Out:
# array(['Insulin Human', 'Insulin Lispro', 'Insulin Glargine',
#        'Insulin Pork', 'Troglitazone', 'Glimepiride', 'Acarbose',
#        'Metformin', 'Rosiglitazone', 'Acetohexamide', 'Miglitol',
#        'Simvastatin', 'Chlorpropamide', 'Nateglinide', 'Tolazamide',
#        'Repaglinide', 'Phenformin', 'Glyburide', 'Glipizide',
#        'Gliclazide', 'Tolbutamide', 'Pioglitazone', 'Gliquidone',
#        'Mitiglinide', 'Sitagliptin', 'Exenatide', 'Pramlintide',
#        'Glisoxepide', 'Insulin Aspart', 'Insulin Detemir',
#        'Insulin Glulisine', 'Glycodiazine', 'Tolrestat', 'Vildagliptin',
#        'Voglibose', 'Alogliptin', 'Dapagliflozin', 'Saxagliptin',
#        'Liraglutide', 'Linagliptin', 'Canagliflozin', 'Empagliflozin',
#        'Albiglutide', 'Dulaglutide', 'Lixisenatide', 'Insulin Degludec'],
#       dtype=object)

# %%
df29 = pd.merge(df18, df12, on='drug_name', how='inner')
df30 = df29.dropna(subset= ['target_effect_diabetes', 'target_gene'])

# %%
df31 = pd.merge(df30, df13, on='target_id', how='outer')
df32 = df31.dropna()

# %%
df32['target_gene'].unique()
# Out:
# array(['INSR', 'IGF1R', 'PRKAB1', 'KCNJ1', 'ABCC8', 'PPARG', 'PRKAA1',
#        'KCNJ8', 'VEGFA', 'DPP4', 'GLP1R', 'MGAM', 'SLC5A2'], dtype=object)

# %%
df33 = df.dropna(subset = ['target_effect_glucose_?', 'target_effect_diabetes']) #only displays samples of drugs that effect both glucose and diabetes

# %%
df34 = pd.merge(df33, df12, on='drug_name', how='inner')
df35 = df34.dropna()
df35.head()
# Out:
#           drug_name  drug_id  target_id  \
# 0    Insulin Lispro  DB00046  BE0000033
# 1    Insulin Lispro  DB00046  BE0000858
# 2  Insulin Glargine  DB00047  BE0000033
# 3  Insulin Glargine  DB00047  BE0000858
# 4         Metformin  DB00331  BE0000254
#
#                                       target_name target_gene  \
# 0                                Insulin receptor        INSR
# 1           Insulin-like growth factor 1 receptor       IGF1R
# 2                                Insulin receptor        INSR
# 3           Insulin-like growth factor 1 receptor       IGF1R
# 4  5'-AMP-activated protein kinase subunit beta-1      PRKAB1
#
#   target_effect_glucose_? target_effect_diabetes  number_of_targets
# 0                    [[]]                   [[]]                  2
# 1                    [[]]                   [[]]                  2
# 2                    [[]]                   [[]]                  2
# 3                    [[]]                   [[]]                  2
# 4                    [[]]                   [[]]                  1

# %%
df36 = pd.merge(df35, df13, on='target_id', how='outer')
df37 = df36.dropna()
df37.loc[df37['target_gene'].isin(["ABCC8"])]
#df37.head()
#df37 includes all samples that affects both diabetes and glucose levels and fits within the criteria of max two target & >two drugs per target
# Out:
#          drug_name  drug_id  target_id  \
# 12  Chlorpropamide  DB00672  BE0000207
# 13     Nateglinide  DB00731  BE0000207
# 14     Repaglinide  DB00912  BE0000207
# 15       Glipizide  DB01067  BE0000207
# 16      Gliclazide  DB01120  BE0000207
# 17     Tolbutamide  DB01124  BE0000207
# 18      Gliquidone  DB01251  BE0000207
# 19     Mitiglinide  DB01252  BE0000207
# 20    Glycodiazine  DB01382  BE0000207
# 25      Tolazamide  DB00839  BE0008670
#
#                                    target_name target_gene  \
# 12  ATP-binding cassette sub-family C member 8       ABCC8
# 13  ATP-binding cassette sub-family C member 8       ABCC8
# 14  ATP-binding cassette sub-family C member 8       ABCC8
# 15  ATP-binding cassette sub-family C member 8       ABCC8
# 16  ATP-binding cassette sub-family C member 8       ABCC8
# 17  ATP-binding cassette sub-family C member 8       ABCC8
# 18  ATP-binding cassette sub-family C member 8       ABCC8
# 19  ATP-binding cassette sub-family C member 8       ABCC8
# 20  ATP-binding cassette sub-family C member 8       ABCC8
# 25             Sulfonylurea receptor 1, Kir6.2       ABCC8
#
#    target_effect_glucose_? target_effect_diabetes  number_of_targets  \
# 12                    [[]]                   [[]]                1.0
# 13                    [[]]                   [[]]                2.0
# 14                    [[]]                   [[]]                2.0
# 15                    [[]]                   [[]]                2.0
# 16                    [[]]                   [[]]                2.0
# 17                    [[]]                   [[]]                2.0
# 18                    [[]]                   [[]]                2.0
# 19                    [[]]                   [[]]                2.0
# 20                    [[]]                   [[]]                2.0
# 25                    [[]]                   [[]]                1.0
#
#     target_freq
# 12         11.0
# 13         11.0
# 14         11.0
# 15         11.0
# 16         11.0
# 17         11.0
# 18         11.0
# 19         11.0
# 20         11.0
# 25          2.0

# %%
df37['target_gene'].unique() #unique genes that effect diabetes AND glucose levels
# Out:
# array(['INSR', 'IGF1R', 'PRKAB1', 'KCNJ1', 'ABCC8', 'PPARG', 'PRKAA1',
#        'KCNJ8', 'VEGFA', 'DPP4', 'GLP1R', 'MGAM', 'SLC5A2'], dtype=object)

# %%
df37['drug_name'].unique()
# Out:
# array(['Insulin Lispro', 'Insulin Glargine', 'Insulin Aspart',
#        'Insulin Detemir', 'Insulin Glulisine', 'Insulin Degludec',
#        'Metformin', 'Acetohexamide', 'Tolbutamide', 'Glycodiazine',
#        'Chlorpropamide', 'Nateglinide', 'Repaglinide', 'Glipizide',
#        'Gliclazide', 'Gliquidone', 'Mitiglinide', 'Tolazamide',
#        'Phenformin', 'Glisoxepide', 'Sitagliptin', 'Vildagliptin',
#        'Alogliptin', 'Saxagliptin', 'Linagliptin', 'Exenatide',
#        'Liraglutide', 'Albiglutide', 'Dulaglutide', 'Lixisenatide',
#        'Voglibose', 'Dapagliflozin', 'Canagliflozin', 'Empagliflozin'],
#       dtype=object)

# %%
df38 = df36.dropna(subset = ['target_effect_glucose_?'])
df38['target_gene'].unique() #Genes Specific to glucose only (othere are overlaps with diabetes-affecting target)
# Out:
# array(['INSR', 'IGF1R', 'PRKAB1', 'KCNJ1', 'ABCC8', 'PPARG', 'PRKAA1',
#        'KCNJ8', 'VEGFA', 'DPP4', 'GLP1R', 'MGAM', 'SLC5A2', 'SLC5A1'],
#       dtype=object)

# %%
df39 = df36.dropna(subset = ['target_effect_diabetes'])
df39['target_gene'].unique() #genes specific to diabetes only (there are overlaps with glucose-affecting targets)
# Out:
# array(['INSR', 'IGF1R', 'PRKAB1', 'KCNJ1', 'ABCC8', 'PPARG', 'PRKAA1',
#        'KCNJ8', 'VEGFA', 'DPP4', 'GLP1R', 'MGAM', 'SLC5A2', 'SLC5A1'],
#       dtype=object)
